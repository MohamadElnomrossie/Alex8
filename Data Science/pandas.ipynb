# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
df=pd.read_csv("house_prices.csv",)

# %%
df.head()
# Out:
#    house_id neighborhood  area  bedrooms  bathrooms      style    price
# 0      1112            B  1188         3          2      ranch   598291
# 1       491            B  3512         5          3  victorian  1744259
# 2      5952            B  1134         3          2      ranch   571669
# 3      3525            A  1940         4          2      ranch   493675
# 4      5108            B  2208         6          4  victorian  1101539

# %%
df.drop(columns=['house_id'],inplace=True)

# %%
del sub
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 del sub
#
# NameError: name 'sub' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6028 entries, 0 to 6027
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   neighborhood  6028 non-null   object
#  1   area          6028 non-null   int64
#  2   bedrooms      6028 non-null   int64
#  3   bathrooms     6028 non-null   int64
#  4   style         6028 non-null   object
#  5   price         6028 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 282.7+ KB

# %%
df['neighborhood'].nunique()
# Out:
# 3

# %%
df['neighborhood'].unique()
# Out:
# array(['B', 'A', 'C'], dtype=object)

# %%
df['neighborhood'].value_counts()
# Out:
# neighborhood
# B    2427
# A    1876
# C    1725
# Name: count, dtype: int64

# %%
df['neighborhood']=df['neighborhood'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6028 entries, 0 to 6027
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   neighborhood  6028 non-null   category
#  1   area          6028 non-null   int64
#  2   bedrooms      6028 non-null   int64
#  3   bathrooms     6028 non-null   int64
#  4   style         6028 non-null   object
#  5   price         6028 non-null   int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 241.6+ KB

# %%
df['style'].value_counts()
df['style']=df['style'].astype('category')

# %%
cols=list(df.columns)

# %%
df=df[cols]

# %%
df.head()
# Out:
#   neighborhood  area  bedrooms  bathrooms      style    price
# 0            B  1188         3          2      ranch   598291
# 1            B  3512         5          3  victorian  1744259
# 2            B  1134         3          2      ranch   571669
# 3            A  1940         4          2      ranch   493675
# 4            B  2208         6          4  victorian  1101539

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6028 entries, 0 to 6027
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   neighborhood  6028 non-null   category
#  1   area          6028 non-null   int64
#  2   bedrooms      6028 non-null   int64
#  3   bathrooms     6028 non-null   int64
#  4   style         6028 non-null   category
#  5   price         6028 non-null   int64
# dtypes: category(2), int64(4)
# memory usage: 200.5 KB

# %%
df.shape
# Out:
# (6028, 6)

# %%
df.iloc[3]
# Out:
# neighborhood         A
# area              1940
# bedrooms             4
# bathrooms            2
# style            ranch
# price           493675
# Name: 3, dtype: object

# %%
df['style'].iloc[3]
# Out:
# 'ranch'

# %%
df.rename(columns={
    'neighborhood':'nh'
},inplace=True)

# %%
df.head()
# Out:
#   nh  area  bedrooms  bathrooms      style    price
# 0  B  1188         3          2      ranch   598291
# 1  B  3512         5          3  victorian  1744259
# 2  B  1134         3          2      ranch   571669
# 3  A  1940         4          2      ranch   493675
# 4  B  2208         6          4  victorian  1101539

# %%
df.describe()
# Out:
#               area     bedrooms    bathrooms         price
# count  6028.000000  6028.000000  6028.000000  6.028000e+03
# mean   2136.849038     3.717651     2.158261  7.542079e+05
# std    1237.481101     1.704650     1.169621  5.236731e+05
# min       0.000000     0.000000     0.000000  1.216700e+04
# 25%    1225.000000     3.000000     2.000000  3.641350e+05
# 50%    1826.000000     4.000000     2.000000  6.357590e+05
# 75%    3129.000000     5.000000     3.000000  9.666752e+05
# max    7447.000000     8.000000     5.000000  3.684602e+06

# %%
df.describe(include='category')
# Out:
#           nh      style
# count   6028       6028
# unique     3          3
# top        B  victorian
# freq    2427       2997

# %%
print(df['price'].min())
print(df['price'].idxmin())
print(df['price'].max())
print(df['price'].idxmax())
# Out:
# 12167
# 3333
# 3684602
# 2852

# %%
df.iloc[3333]
# Out:
# nh               C
# area             0
# bedrooms         1
# bathrooms        0
# style        lodge
# price        12167
# Name: 3333, dtype: object

# %%
df.values
# Out:
# array([['B', 1188, 3, 2, 'ranch', 598291],
#        ['B', 3512, 5, 3, 'victorian', 1744259],
#        ['B', 1134, 3, 2, 'ranch', 571669],
#        ...,
#        ['B', 1518, 2, 1, 'lodge', 760829],
#        ['C', 2270, 4, 2, 'ranch', 575515],
#        ['C', 3355, 5, 3, 'victorian', 844747]], dtype=object)

# %%
df['price'].values
# Out:
# array([ 598291, 1744259,  571669, ...,  760829,  575515,  844747])

# %%
df['nh'].replace(to_replace=[0,1,2],value='aaa',inplace=True)
# Out:
# C:\Users\Mohammed\AppData\Local\Temp\ipykernel_10584\3896031531.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['nh'].replace(to_replace=[0,1,2],value='aaa',inplace=True)

# %%
df.head()
# Out:
#   nh  area  bedrooms  bathrooms      style    price
# 0  B  1188         3          2      ranch   598291
# 1  B  3512         5          3  victorian  1744259
# 2  B  1134         3          2      ranch   571669
# 3  A  1940         4          2      ranch   493675
# 4  B  2208         6          4  victorian  1101539

# %%
df['nh'].replace({'aaa':12},inplace=True)
# Out:
# C:\Users\Mohammed\AppData\Local\Temp\ipykernel_10584\2241511680.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['nh'].replace({'aaa':12},inplace=True)

# %%
df.head()
# Out:
#   nh  area  bedrooms  bathrooms      style    price
# 0  B  1188         3          2      ranch   598291
# 1  B  3512         5          3  victorian  1744259
# 2  B  1134         3          2      ranch   571669
# 3  A  1940         4          2      ranch   493675
# 4  B  2208         6          4  victorian  1101539

# %%
df.head()
# Out:
#   nh  area  bedrooms  bathrooms      style    price
# 0  B  1188         3          2      ranch   598291
# 1  B  3512         5          3  victorian  1744259
# 2  B  1134         3          2      ranch   571669
# 3  A  1940         4          2      ranch   493675
# 4  B  2208         6          4  victorian  1101539

# %%
sub=df.sort_values(by='price',ascending=False).reset_index(drop=True)

# %%
# sub.reset_index(drop=True,inplace=True)

# %%
sub.head()
# Out:
#   nh  area  bedrooms  bathrooms      style    price
# 0  B  7447         8          5  victorian  3684602
# 1  B  7142         8          5  victorian  3534237
# 2  B  6992         8          5  victorian  3460287
# 3  B  6922         8          5  victorian  3425777
# 4  B  6392         8          5  victorian  3164487

# %%
def text_encode(text):
    if text=='victorian':
        return 0
    elif text=='ranch':
        return 1
    elif text=='lodge':
        return 2

# %%
df['encoded_style']=df['style'].apply(text_encode)

# %%
df.head()
# Out:
#   nh  area  bedrooms  bathrooms      style    price encoded_style
# 0  B  1188         3          2      ranch   598291             1
# 1  B  3512         5          3  victorian  1744259             0
# 2  B  1134         3          2      ranch   571669             1
# 3  A  1940         4          2      ranch   493675             1
# 4  B  2208         6          4  victorian  1101539             0

# %%
df[(df['style']=='ranch') & (df['price']>500000)]
# Out:
#      nh  area  bedrooms  bathrooms  style    price encoded_style
# 0     B  1188         3          2  ranch   598291             1
# 2     B  1134         3          2  ranch   571669             1
# 12    A  2275         4          2  ranch   576755             1
# 25    B  1174         3          2  ranch   591389             1
# 41    B  1149         2          1  ranch   578912             1
# ...  ..   ...       ...        ...    ...      ...           ...
# 5985  B  2395         4          2  ranch  1193426             1
# 5999  C  1976         4          2  ranch   502603             1
# 6003  A  2294         4          2  ranch   581467             1
# 6009  A  2000         4          2  ranch   508555             1
# 6026  C  2270         4          2  ranch   575515             1
#
# [925 rows x 7 columns]

# %%
df=pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
pd.DataFrame(df.isnull().sum()).T
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0   0           0         0          259        0       0   1369         0
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0            0          0          0          0             0           0
#
#    Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0           0         0           0            0            0          0
#
#    YearRemodAdd  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  \
# 0             0          0         0            0            0         872
#
#    MasVnrArea  ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  \
# 0           8          0          0           0        37        37
#
#    BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  BsmtFinSF2  \
# 0            38            37           0            38           0
#
#    BsmtUnfSF  TotalBsmtSF  Heating  HeatingQC  CentralAir  Electrical  \
# ...

# %%
pd.DataFrame(df.isnull().sum()).T
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0   0           0         0            0        0       0   1369         0
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0            0          0          0          0             0           0
#
#    Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0           0         0           0            0            0          0
#
#    YearRemodAdd  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  \
# 0             0          0         0            0            0         872
#
#    MasVnrArea  ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  \
# 0           8          0          0           0        37        37
#
#    BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  BsmtFinSF2  \
# 0            38            37           0            38           0
#
#    BsmtUnfSF  TotalBsmtSF  Heating  HeatingQC  CentralAir  Electrical  \
# ...

# %%
df.dropna(subset=['LotFrontage'])
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
mean=df['LotFrontage'].mean()

# %%
df['LotFrontage'].fillna(mean,inplace=True)
# Out:
# C:\Users\Mohammed\AppData\Local\Temp\ipykernel_10584\920399361.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['LotFrontage'].fillna(mean,inplace=True)
