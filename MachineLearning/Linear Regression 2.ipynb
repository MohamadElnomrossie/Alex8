# %%
from sklearn.datasets import fetch_california_housing,load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
import numpy as np
import joblib

# %%
X,y=fetch_california_housing(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(sub,y,random_state=42)

# %%
for t in range(X.shape[1]+1):
    if t==0:
        continue
    sub=X[:,:t]
    scaler=MinMaxScaler()
    sub=scaler.fit_transform(sub)
    X_train,X_test,y_train,y_test=train_test_split(sub,y,random_state=42)
    lr=LinearRegression()
    lr.fit(X_train,y_train)
    print(lr.score(X_test,y_test))
    print("="*60)
# Out:
# 0.47083837938023376
# ...
# 0.5080786160589955
# ...
# 0.5118251230159078
# ...
# 0.5237440518573144
# ...
# 0.523860893009753
# ...
# 0.5248613055247972
# ...
# 0.5290133054812776
# ...
# 0.5910509795491352
# ...

# %%
scaler=MinMaxScaler()
X=scaler.fit_transform(X)#////////////////////
pl=PolynomialFeatures(degree=2)
X_transformed=pl.fit_transform(X)#////////////////////////
X_train,X_test,y_train,y_test=train_test_split(X_transformed,y,random_state=42)
lr=LinearRegression()
lr.fit(X_train,y_train)#/////////////////////////
print(lr.score(X_test,y_test))
print("="*60)
# Out:
# 0.6563005885267881
# ...

# %%
trans=pl.transform(X[0].reshape(1,-1))
predicted=lr.predict(trans)

# %%
pl=Pipeline([('scaler',MinMaxScaler()),
             ('pl',PolynomialFeatures(degree=2)),
             ('estimator',LinearRegression())])
X,y=fetch_california_housing(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42)
pl.fit(X_train,y_train)
print(pl.score(X_test,y_test))
# Out:
# 0.6563005880757488

# %%
pl
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()), ('pl', PolynomialFeatures()),
#                 ('estimator', LinearRegression())])

# %%
pl.predict

# %%
pl.n_features_in_
# Out:
# 8

# %%
pl=PolynomialFeatures(degree=2)

# %%
pl=Pipeline([('scaler',MinMaxScaler()),
             ('pl',PolynomialFeatures(degree=2)),
             ('estimator',LinearRegression())])

# %%
pl
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()), ('pl', PolynomialFeatures()),
#                 ('estimator', LinearRegression())])

# %%
pl=PolynomialFeatures(degree=2)

# %%
pl.fit_transform(X)
# Out:
# array([[ 1.00000000e+00,  8.32520000e+00,  4.10000000e+01, ...,
#          1.43489440e+03, -4.63007240e+03,  1.49401729e+04],
#        [ 1.00000000e+00,  8.30140000e+00,  2.10000000e+01, ...,
#          1.43337960e+03, -4.62724920e+03,  1.49377284e+04],
#        [ 1.00000000e+00,  7.25740000e+00,  5.20000000e+01, ...,
#          1.43262250e+03, -4.62678400e+03,  1.49426176e+04],
#        ...,
#        [ 1.00000000e+00,  1.70000000e+00,  1.70000000e+01, ...,
#          1.55472490e+03, -4.77970460e+03,  1.46942884e+04],
#        [ 1.00000000e+00,  1.86720000e+00,  1.80000000e+01, ...,
#          1.55472490e+03, -4.78364760e+03,  1.47185424e+04],
#        [ 1.00000000e+00,  2.38860000e+00,  1.60000000e+01, ...,
#          1.54999690e+03, -4.77321880e+03,  1.46991376e+04]])

# %%
joblib.dump(pl,'model.pkl')
# Out:
# ['model.pkl']

# %%
model=joblib.load('model.pkl')

# %%
model
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()), ('pl', PolynomialFeatures()),
#                 ('estimator', LinearRegression())])
